# %%
# !python -V
# Out:
# Python 3.9.21

# %%
# !pip uninstall scikit-learn -y
# !pip install scikit-learn==1.6.1
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.6.1
#   Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages (from scikit-learn==1.6.1) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages (from scikit-learn==1.6.1) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages (from scikit-learn==1.6.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages (from scikit-learn==1.6.1) (3.6.0)
# Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.6.1

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import root_mean_squared_error

# %%
import sklearn
import sys
print("sklearn version:", sklearn.__version__)
print("python executable:", sys.executable)
# Out:
# sklearn version: 1.6.1
# python executable: /Users/zihaozhou/.conda/envs/exp-tracking-env/bin/python

# %%
from sklearn.metrics import mean_squared_error
import inspect

print(mean_squared_error)
print(inspect.getfile(mean_squared_error))
# Out:
# <function mean_squared_error at 0x14c8c7c10>
# /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/utils/_param_validation.py

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1743464550778, experiment_id='1', last_update_time=1743464550778, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
print(mlflow.__version__)
# Out:
# 2.21.3

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('data/green_tripdata_2023-01.parquet')
df_val = read_dataframe('data/green_tripdata_2023-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (65946, 62574)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mse = mean_squared_error(y_val, y_pred)**0.5
mse
# Out:
# 6.037585607307625

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "data/green_tripdata_2023-01.parquet")
    mlflow.log_param("valid-data-path", "data/green_tripdata_2023-02.parquet")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred)**0.5
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred)**0.5
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:7.78817
# [1]	validation-rmse:6.81558
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [21:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [2]	validation-rmse:6.22256
# [3]	validation-rmse:5.86902
# [4]	validation-rmse:5.66049
# [5]	validation-rmse:5.54098
# [6]	validation-rmse:5.46869
# [7]	validation-rmse:5.42044
# [8]	validation-rmse:5.39151
# [9]	validation-rmse:5.36926
# [10]	validation-rmse:5.35458
# [11]	validation-rmse:5.34420
# [12]	validation-rmse:5.33642
# [13]	validation-rmse:5.32968
# [14]	validation-rmse:5.32611
# [15]	validation-rmse:5.32057
# [16]	validation-rmse:5.31684
# [17]	validation-rmse:5.31311
# [18]	validation-rmse:5.30948
# [19]	validation-rmse:5.30819
# [20]	validation-rmse:5.30598
# [21]	validation-rmse:5.30481
# [22]	validation-rmse:5.30114
# [23]	validation-rmse:5.30018
# [24]	validation-rmse:5.29777
# [25]	validation-rmse:5.29727
# [26]	validation-rmse:5.29550
# [27]	validation-rmse:5.29467
# [28]	validation-rmse:5.29136
# [29]	validation-rmse:5.29021
# [30]	validation-rmse:5.28951
# [31]	validation-rmse:5.28726
# [32]	validation-rmse:5.28678
# [33]	validation-rmse:5.28331
# [34]	validation-rmse:5.28275
# [35]	validation-rmse:5.28171
# [36]	validation-rmse:5.28096
# [37]	validation-rmse:5.28021
# [38]	validation-rmse:5.27957
# [39]	validation-rmse:5.27742
# [40]	validation-rmse:5.27641
# [41]	validation-rmse:5.27650
# [42]	validation-rmse:5.27337
# [43]	validation-rmse:5.27249
# [44]	validation-rmse:5.27133
# [45]	validation-rmse:5.27119
# [46]	validation-rmse:5.27039
# [47]	validation-rmse:5.27026
# [48]	validation-rmse:5.26754
# [49]	validation-rmse:5.26696
# [50]	validation-rmse:5.26429
# [51]	validation-rmse:5.26317
# [52]	validation-rmse:5.26187
# [53]	validation-rmse:5.25999
# [54]	validation-rmse:5.25916
# [55]	validation-rmse:5.25891
# [56]	validation-rmse:5.25760
# [57]	validation-rmse:5.25665
# [58]	validation-rmse:5.25547
# [59]	validation-rmse:5.25482
# [60]	validation-rmse:5.25365
# [61]	validation-rmse:5.25305
# [62]	validation-rmse:5.25208
# [63]	validation-rmse:5.25182
# [64]	validation-rmse:5.25156
# [65]	validation-rmse:5.25070
# [66]	validation-rmse:5.25039
# [67]	validation-rmse:5.25000
# [68]	validation-rmse:5.24930
# [69]	validation-rmse:5.24877
# [70]	validation-rmse:5.24863
# [71]	validation-rmse:5.24851
# [72]	validation-rmse:5.24740
# [73]	validation-rmse:5.24718
# [74]	validation-rmse:5.24644
# [75]	validation-rmse:5.24590
# [76]	validation-rmse:5.24561
# [77]	validation-rmse:5.24507
# [78]	validation-rmse:5.24502
# [79]	validation-rmse:5.24393
# [80]	validation-rmse:5.24393
# [81]	validation-rmse:5.24337
# [82]	validation-rmse:5.24321
# [83]	validation-rmse:5.24277
# [84]	validation-rmse:5.24283
# [85]	validation-rmse:5.24192
# [86]	validation-rmse:5.24196
# [87]	validation-rmse:5.24127
# [88]	validation-rmse:5.24091
# [89]	validation-rmse:5.24055
# [90]	validation-rmse:5.24032
# [91]	validation-rmse:5.24019
# [92]	validation-rmse:5.23984
# [93]	validation-rmse:5.23946
# [94]	validation-rmse:5.23882
# [95]	validation-rmse:5.23884
# [96]	validation-rmse:5.23854
# [97]	validation-rmse:5.23828
# [98]	validation-rmse:5.23867
# [99]	validation-rmse:5.23751
# [100]	validation-rmse:5.23751
# [101]	validation-rmse:5.23698
# [102]	validation-rmse:5.23577
# [103]	validation-rmse:5.23549
# [104]	validation-rmse:5.23473
# [105]	validation-rmse:5.23451
# [106]	validation-rmse:5.23409
# [107]	validation-rmse:5.23381
# [108]	validation-rmse:5.23340
# [109]	validation-rmse:5.23331
# [110]	validation-rmse:5.23264
# [111]	validation-rmse:5.23264
# [112]	validation-rmse:5.23252
# [113]	validation-rmse:5.23246
# [114]	validation-rmse:5.23211
# [115]	validation-rmse:5.23213
# [116]	validation-rmse:5.23179
# [117]	validation-rmse:5.23167
# [118]	validation-rmse:5.23168
# [119]	validation-rmse:5.23146
# [120]	validation-rmse:5.23092
# [121]	validation-rmse:5.23096
# [122]	validation-rmse:5.23042
# [123]	validation-rmse:5.23033
# [124]	validation-rmse:5.22996
# [125]	validation-rmse:5.22998
# [126]	validation-rmse:5.22924
# [127]	validation-rmse:5.22903
# [128]	validation-rmse:5.22894
# [129]	validation-rmse:5.22904
# [130]	validation-rmse:5.22856
# [131]	validation-rmse:5.22824
# [132]	validation-rmse:5.22821
# [133]	validation-rmse:5.22844
# [134]	validation-rmse:5.22823
# [135]	validation-rmse:5.22813
# [136]	validation-rmse:5.22781
# [137]	validation-rmse:5.22774
# [138]	validation-rmse:5.22742
# [139]	validation-rmse:5.22740
# [140]	validation-rmse:5.22774
# [141]	validation-rmse:5.22742
# [142]	validation-rmse:5.22704
# [143]	validation-rmse:5.22705
# [144]	validation-rmse:5.22677
# [145]	validation-rmse:5.22665
# [146]	validation-rmse:5.22664
# [147]	validation-rmse:5.22652
# [148]	validation-rmse:5.22620
# [149]	validation-rmse:5.22621
# [150]	validation-rmse:5.22602
# [151]	validation-rmse:5.22604
# [152]	validation-rmse:5.22610
# [153]	validation-rmse:5.22599
# [154]	validation-rmse:5.22590
# [155]	validation-rmse:5.22587
# [156]	validation-rmse:5.22599
# [157]	validation-rmse:5.22543
# [158]	validation-rmse:5.22495
# [159]	validation-rmse:5.22476
# [160]	validation-rmse:5.22470
# [161]	validation-rmse:5.22482
# [162]	validation-rmse:5.22488
# [163]	validation-rmse:5.22510
# [164]	validation-rmse:5.22497
# [165]	validation-rmse:5.22459
# [166]	validation-rmse:5.22413
# [167]	validation-rmse:5.22380
# [168]	validation-rmse:5.22358
# [169]	validation-rmse:5.22303
# [170]	validation-rmse:5.22304
# [171]	validation-rmse:5.22298
# [172]	validation-rmse:5.22298
# [173]	validation-rmse:5.22259
# [174]	validation-rmse:5.22255
# [175]	validation-rmse:5.22230
# [176]	validation-rmse:5.22215
# [177]	validation-rmse:5.22224
# [178]	validation-rmse:5.22217
# [179]	validation-rmse:5.22188
# [180]	validation-rmse:5.22195
# [181]	validation-rmse:5.22161
# [182]	validation-rmse:5.22156
# [183]	validation-rmse:5.22143
# [184]	validation-rmse:5.22128
# [185]	validation-rmse:5.22104
# [186]	validation-rmse:5.22083
# [187]	validation-rmse:5.22085
# [188]	validation-rmse:5.21946
# [189]	validation-rmse:5.21950
# [190]	validation-rmse:5.21933
# [191]	validation-rmse:5.21927
# [192]	validation-rmse:5.21846
# [193]	validation-rmse:5.21840
# [194]	validation-rmse:5.21849
# [195]	validation-rmse:5.21773
# [196]	validation-rmse:5.21732
# [197]	validation-rmse:5.21722
# [198]	validation-rmse:5.21749
# [199]	validation-rmse:5.21695
# [200]	validation-rmse:5.21710
# [201]	validation-rmse:5.21681
# [202]	validation-rmse:5.21656
# [203]	validation-rmse:5.21640
# [204]	validation-rmse:5.21629
# [205]	validation-rmse:5.21572
# [206]	validation-rmse:5.21555
# [207]	validation-rmse:5.21554
# [208]	validation-rmse:5.21529
# [209]	validation-rmse:5.21535
# [210]	validation-rmse:5.21536
# [211]	validation-rmse:5.21533
# [212]	validation-rmse:5.21534
# [213]	validation-rmse:5.21481
# [214]	validation-rmse:5.21447
# [215]	validation-rmse:5.21458
# [216]	validation-rmse:5.21498
# [217]	validation-rmse:5.21476
# [218]	validation-rmse:5.21474
# [219]	validation-rmse:5.21439
# [220]	validation-rmse:5.21440
# [221]	validation-rmse:5.21445
# [222]	validation-rmse:5.21453
# [223]	validation-rmse:5.21428
# [224]	validation-rmse:5.21419
# [225]	validation-rmse:5.21407
# [226]	validation-rmse:5.21405
# [227]	validation-rmse:5.21394
# [228]	validation-rmse:5.21397
# [229]	validation-rmse:5.21369
# [230]	validation-rmse:5.21371
# [231]	validation-rmse:5.21355
# [232]	validation-rmse:5.21345
# [233]	validation-rmse:5.21348
# [234]	validation-rmse:5.21333
# [235]	validation-rmse:5.21331
# [236]	validation-rmse:5.21329
# [237]	validation-rmse:5.21334
# [238]	validation-rmse:5.21318
# [239]	validation-rmse:5.21322
# [240]	validation-rmse:5.21290
# [241]	validation-rmse:5.21300
# [242]	validation-rmse:5.21295
# [243]	validation-rmse:5.21296
# [244]	validation-rmse:5.21310
# [245]	validation-rmse:5.21310
# [246]	validation-rmse:5.21296
# [247]	validation-rmse:5.21317
# [248]	validation-rmse:5.21301
# [249]	validation-rmse:5.21267
# [250]	validation-rmse:5.21250
# [251]	validation-rmse:5.21255
# [252]	validation-rmse:5.21231
# [253]	validation-rmse:5.21238
# [254]	validation-rmse:5.21234
# [255]	validation-rmse:5.21232
# [256]	validation-rmse:5.21239
# [257]	validation-rmse:5.21196
# [258]	validation-rmse:5.21087
# [259]	validation-rmse:5.21111
# [260]	validation-rmse:5.21144
# [261]	validation-rmse:5.21161
# [262]	validation-rmse:5.21167
# [263]	validation-rmse:5.21158
# [264]	validation-rmse:5.21161
# [265]	validation-rmse:5.21144
# [266]	validation-rmse:5.21160
# [267]	validation-rmse:5.21137
# [268]	validation-rmse:5.21129
# [269]	validation-rmse:5.21124
# [270]	validation-rmse:5.21091
# [271]	validation-rmse:5.21061
# [272]	validation-rmse:5.21064
# [273]	validation-rmse:5.21042
# [274]	validation-rmse:5.20986
# [275]	validation-rmse:5.20993
# [276]	validation-rmse:5.21010
# [277]	validation-rmse:5.20999
# [278]	validation-rmse:5.21000
# [279]	validation-rmse:5.21010
# [280]	validation-rmse:5.21013
# [281]	validation-rmse:5.20996
# [282]	validation-rmse:5.20960
# [283]	validation-rmse:5.20966
# [284]	validation-rmse:5.20969
# [285]	validation-rmse:5.20979
# [286]	validation-rmse:5.20962
# [287]	validation-rmse:5.20949
# [288]	validation-rmse:5.20949
# [289]	validation-rmse:5.20944
# [290]	validation-rmse:5.20944
# [291]	validation-rmse:5.20931
# [292]	validation-rmse:5.20927
# [293]	validation-rmse:5.20916
# [294]	validation-rmse:5.20920
# [295]	validation-rmse:5.20911
# [296]	validation-rmse:5.20903
# [297]	validation-rmse:5.20897
# [298]	validation-rmse:5.20897
# [299]	validation-rmse:5.20895
# [300]	validation-rmse:5.20894
# [301]	validation-rmse:5.20890
# [302]	validation-rmse:5.20880
# [303]	validation-rmse:5.20875
# [304]	validation-rmse:5.20879
# [305]	validation-rmse:5.20882
# [306]	validation-rmse:5.20876
# [307]	validation-rmse:5.20859
# [308]	validation-rmse:5.20844
# [309]	validation-rmse:5.20845
# [310]	validation-rmse:5.20839
# [311]	validation-rmse:5.20832
# [312]	validation-rmse:5.20832
# [313]	validation-rmse:5.20838
# [314]	validation-rmse:5.20843
# [315]	validation-rmse:5.20837
# [316]	validation-rmse:5.20846
# [317]	validation-rmse:5.20824
# [318]	validation-rmse:5.20830
# [319]	validation-rmse:5.20817
# [320]	validation-rmse:5.20815
# [321]	validation-rmse:5.20805
# [322]	validation-rmse:5.20805
# [323]	validation-rmse:5.20787
# [324]	validation-rmse:5.20792
# [325]	validation-rmse:5.20794
# [326]	validation-rmse:5.20796
# [327]	validation-rmse:5.20781
# [328]	validation-rmse:5.20739
# [329]	validation-rmse:5.20715
# [330]	validation-rmse:5.20720
# [331]	validation-rmse:5.20702
# [332]	validation-rmse:5.20712
# [333]	validation-rmse:5.20703
# [334]	validation-rmse:5.20710
# [335]	validation-rmse:5.20707
# [336]	validation-rmse:5.20704
# [337]	validation-rmse:5.20688
# [338]	validation-rmse:5.20677
# [339]	validation-rmse:5.20650
# [340]	validation-rmse:5.20654
# [341]	validation-rmse:5.20671
# [342]	validation-rmse:5.20664
# [343]	validation-rmse:5.20654
# [344]	validation-rmse:5.20639
# [345]	validation-rmse:5.20619
# [346]	validation-rmse:5.20608
# [347]	validation-rmse:5.20619
# [348]	validation-rmse:5.20623
# [349]	validation-rmse:5.20619
# [350]	validation-rmse:5.20594
# [351]	validation-rmse:5.20583
# [352]	validation-rmse:5.20563
# [353]	validation-rmse:5.20577
# [354]	validation-rmse:5.20566
# [355]	validation-rmse:5.20509
# [356]	validation-rmse:5.20534
# [357]	validation-rmse:5.20564
# [358]	validation-rmse:5.20551
# [359]	validation-rmse:5.20540
# [360]	validation-rmse:5.20540
# [361]	validation-rmse:5.20506
# [362]	validation-rmse:5.20508
# [363]	validation-rmse:5.20503
# [364]	validation-rmse:5.20469
# [365]	validation-rmse:5.20485
# [366]	validation-rmse:5.20488
# [367]	validation-rmse:5.20470
# [368]	validation-rmse:5.20459
# [369]	validation-rmse:5.20446
# [370]	validation-rmse:5.20446
# [371]	validation-rmse:5.20449
# [372]	validation-rmse:5.20438
# [373]	validation-rmse:5.20438
# [374]	validation-rmse:5.20443
# [375]	validation-rmse:5.20436
# [376]	validation-rmse:5.20439
# [377]	validation-rmse:5.20433
# [378]	validation-rmse:5.20437
# [379]	validation-rmse:5.20456
# [380]	validation-rmse:5.20464
# [381]	validation-rmse:5.20444
# [382]	validation-rmse:5.20437
# [383]	validation-rmse:5.20428
# [384]	validation-rmse:5.20432
# [385]	validation-rmse:5.20405
# [386]	validation-rmse:5.20412
# [387]	validation-rmse:5.20379
# [388]	validation-rmse:5.20381
# [389]	validation-rmse:5.20371
# [390]	validation-rmse:5.20384
# [391]	validation-rmse:5.20374
# [392]	validation-rmse:5.20367
# [393]	validation-rmse:5.20380
# [394]	validation-rmse:5.20374
# [395]	validation-rmse:5.20375
# [396]	validation-rmse:5.20378
# [397]	validation-rmse:5.20382
# [398]	validation-rmse:5.20382
# [399]	validation-rmse:5.20381
# [400]	validation-rmse:5.20325
# [401]	validation-rmse:5.20315
# [402]	validation-rmse:5.20332
# [403]	validation-rmse:5.20346
# [404]	validation-rmse:5.20356
# [405]	validation-rmse:5.20359
# [406]	validation-rmse:5.20322
# [407]	validation-rmse:5.20317
# [408]	validation-rmse:5.20313
# [409]	validation-rmse:5.20307
# [410]	validation-rmse:5.20280
# [411]	validation-rmse:5.20283
# [412]	validation-rmse:5.20285
# [413]	validation-rmse:5.20268
# [414]	validation-rmse:5.20273
# [415]	validation-rmse:5.20274
# [416]	validation-rmse:5.20262
# [417]	validation-rmse:5.20265
# [418]	validation-rmse:5.20264
# [419]	validation-rmse:5.20264
# [420]	validation-rmse:5.20251
# [421]	validation-rmse:5.20222
# [422]	validation-rmse:5.20231
# [423]	validation-rmse:5.20244
# [424]	validation-rmse:5.20245
# [425]	validation-rmse:5.20232
# [426]	validation-rmse:5.20231
# [427]	validation-rmse:5.20230
# [428]	validation-rmse:5.20224
# [429]	validation-rmse:5.20207
# [430]	validation-rmse:5.20201
# [431]	validation-rmse:5.20210
# [432]	validation-rmse:5.20198
# [433]	validation-rmse:5.20199
# [434]	validation-rmse:5.20186
# [435]	validation-rmse:5.20190
# [436]	validation-rmse:5.20197
# [437]	validation-rmse:5.20219
# [438]	validation-rmse:5.20200
# [439]	validation-rmse:5.20209
# [440]	validation-rmse:5.20207
# [441]	validation-rmse:5.20212
# [442]	validation-rmse:5.20196
# [443]	validation-rmse:5.20199
# [444]	validation-rmse:5.20197
# [445]	validation-rmse:5.20184
# [446]	validation-rmse:5.20192
# [447]	validation-rmse:5.20200
# [448]	validation-rmse:5.20188
# [449]	validation-rmse:5.20199
# [450]	validation-rmse:5.20204
# [451]	validation-rmse:5.20200
# [452]	validation-rmse:5.20209
# [453]	validation-rmse:5.20216
# [454]	validation-rmse:5.20210
# [455]	validation-rmse:5.20214
# [456]	validation-rmse:5.20211
# [457]	validation-rmse:5.20213
# [458]	validation-rmse:5.20207
# [459]	validation-rmse:5.20212
# [460]	validation-rmse:5.20205
# [461]	validation-rmse:5.20211
# [462]	validation-rmse:5.20188
# [463]	validation-rmse:5.20193
# [464]	validation-rmse:5.20185
# [465]	validation-rmse:5.20186
# [466]	validation-rmse:5.20177
# [467]	validation-rmse:5.20175
# [468]	validation-rmse:5.20180
# [469]	validation-rmse:5.20173
# [470]	validation-rmse:5.20167
# [471]	validation-rmse:5.20158
# [472]	validation-rmse:5.20145
# [473]	validation-rmse:5.20152
# [474]	validation-rmse:5.20129
# [475]	validation-rmse:5.20142
# [476]	validation-rmse:5.20136
# [477]	validation-rmse:5.20146
# [478]	validation-rmse:5.20145
# [479]	validation-rmse:5.20149
# [480]	validation-rmse:5.20135
# [481]	validation-rmse:5.20144
# [482]	validation-rmse:5.20132
# [483]	validation-rmse:5.20133
# [484]	validation-rmse:5.20140
# [485]	validation-rmse:5.20149
# [486]	validation-rmse:5.20138
# [487]	validation-rmse:5.20118
# [488]	validation-rmse:5.20104
# [489]	validation-rmse:5.20118
# [490]	validation-rmse:5.20107
# [491]	validation-rmse:5.20107
# [492]	validation-rmse:5.20094
# [493]	validation-rmse:5.20092
# [494]	validation-rmse:5.20092
# [495]	validation-rmse:5.20093
# [496]	validation-rmse:5.20074
# [497]	validation-rmse:5.20068
# [498]	validation-rmse:5.20071
# [499]	validation-rmse:5.20069
# [500]	validation-rmse:5.20074
# [501]	validation-rmse:5.20074
# [502]	validation-rmse:5.20082
# [503]	validation-rmse:5.20081
# [504]	validation-rmse:5.20075
# [505]	validation-rmse:5.20069
# [506]	validation-rmse:5.20075
# [507]	validation-rmse:5.20076
# [508]	validation-rmse:5.20081
# [509]	validation-rmse:5.20068
# [510]	validation-rmse:5.20062
# [511]	validation-rmse:5.20055
# [512]	validation-rmse:5.20068
# [513]	validation-rmse:5.20064
# [514]	validation-rmse:5.20061
# [515]	validation-rmse:5.20061
# [516]	validation-rmse:5.20054
# [517]	validation-rmse:5.20046
# [518]	validation-rmse:5.20056
# [519]	validation-rmse:5.20046
# [520]	validation-rmse:5.20056
# [521]	validation-rmse:5.20055
# [522]	validation-rmse:5.20062
# [523]	validation-rmse:5.20051
# [524]	validation-rmse:5.20052
# [525]	validation-rmse:5.20057
# [526]	validation-rmse:5.20062
# [527]	validation-rmse:5.20062
# [528]	validation-rmse:5.20023
# [529]	validation-rmse:5.20034
# [530]	validation-rmse:5.20034
# [531]	validation-rmse:5.20023
# [532]	validation-rmse:5.20033
# [533]	validation-rmse:5.20033
# [534]	validation-rmse:5.20028
# [535]	validation-rmse:5.20034
# [536]	validation-rmse:5.20028
# [537]	validation-rmse:5.20023
# [538]	validation-rmse:5.20030
# [539]	validation-rmse:5.20040
# [540]	validation-rmse:5.20032
# [541]	validation-rmse:5.20030
# [542]	validation-rmse:5.20048
# [543]	validation-rmse:5.20036
# [544]	validation-rmse:5.20029
# [545]	validation-rmse:5.20029
# [546]	validation-rmse:5.20016
# [547]	validation-rmse:5.19987
# [548]	validation-rmse:5.19983
# [549]	validation-rmse:5.19980
# [550]	validation-rmse:5.19970
# [551]	validation-rmse:5.19951
# [552]	validation-rmse:5.19938
# [553]	validation-rmse:5.19941
# [554]	validation-rmse:5.19949
# [555]	validation-rmse:5.19949
# [556]	validation-rmse:5.19965
# [557]	validation-rmse:5.19969
# [558]	validation-rmse:5.19964
# [559]	validation-rmse:5.19964
# [560]	validation-rmse:5.19965
# [561]	validation-rmse:5.19956
# [562]	validation-rmse:5.19952
# [563]	validation-rmse:5.19921
# [564]	validation-rmse:5.19905
# [565]	validation-rmse:5.19908
# [566]	validation-rmse:5.19904
# [567]	validation-rmse:5.19917
# [568]	validation-rmse:5.19915
# [569]	validation-rmse:5.19925
# [570]	validation-rmse:5.19927
# [571]	validation-rmse:5.19928
# [572]	validation-rmse:5.19927
# [573]	validation-rmse:5.19937
# [574]	validation-rmse:5.19917
# [575]	validation-rmse:5.19920
# [576]	validation-rmse:5.19921
# [577]	validation-rmse:5.19917
# [578]	validation-rmse:5.19901
# [579]	validation-rmse:5.19890
# [580]	validation-rmse:5.19887
# [581]	validation-rmse:5.19882
# [582]	validation-rmse:5.19868
# [583]	validation-rmse:5.19870
# [584]	validation-rmse:5.19838
# [585]	validation-rmse:5.19845
# [586]	validation-rmse:5.19855
# [587]	validation-rmse:5.19845
# [588]	validation-rmse:5.19870
# [589]	validation-rmse:5.19850
# [590]	validation-rmse:5.19851
# [591]	validation-rmse:5.19863
# [592]	validation-rmse:5.19852
# [593]	validation-rmse:5.19864
# [594]	validation-rmse:5.19868
# [595]	validation-rmse:5.19856
# [596]	validation-rmse:5.19846
# [597]	validation-rmse:5.19815
# [598]	validation-rmse:5.19827
# [599]	validation-rmse:5.19827
# [600]	validation-rmse:5.19811
# [601]	validation-rmse:5.19813
# [602]	validation-rmse:5.19813
# [603]	validation-rmse:5.19783
# [604]	validation-rmse:5.19802
# [605]	validation-rmse:5.19795
# [606]	validation-rmse:5.19796
# [607]	validation-rmse:5.19799
# [608]	validation-rmse:5.19781
# [609]	validation-rmse:5.19780
# [610]	validation-rmse:5.19800
# [611]	validation-rmse:5.19789
# [612]	validation-rmse:5.19801
# [613]	validation-rmse:5.19791
# [614]	validation-rmse:5.19807
# [615]	validation-rmse:5.19831
# [616]	validation-rmse:5.19835
# [617]	validation-rmse:5.19824
# [618]	validation-rmse:5.19827
# [619]	validation-rmse:5.19823
# [620]	validation-rmse:5.19822
# [621]	validation-rmse:5.19828
# [622]	validation-rmse:5.19833
# [623]	validation-rmse:5.19830
# [624]	validation-rmse:5.19833
# [625]	validation-rmse:5.19830
# [626]	validation-rmse:5.19832
# [627]	validation-rmse:5.19824
# [628]	validation-rmse:5.19814
# [629]	validation-rmse:5.19812
# [630]	validation-rmse:5.19821
# [631]	validation-rmse:5.19827
# [632]	validation-rmse:5.19826
# [633]	validation-rmse:5.19824
# [634]	validation-rmse:5.19819
# [635]	validation-rmse:5.19823
# [636]	validation-rmse:5.19818
# [637]	validation-rmse:5.19810
# [638]	validation-rmse:5.19809
# [639]	validation-rmse:5.19809
# [640]	validation-rmse:5.19802
# [641]	validation-rmse:5.19803
# [642]	validation-rmse:5.19795
# [643]	validation-rmse:5.19797
# [644]	validation-rmse:5.19796
# [645]	validation-rmse:5.19783
# [646]	validation-rmse:5.19786
# [647]	validation-rmse:5.19781
# [648]	validation-rmse:5.19797
# [649]	validation-rmse:5.19816
# [650]	validation-rmse:5.19845
# [651]	validation-rmse:5.19858
# [652]	validation-rmse:5.19860
# [653]	validation-rmse:5.19848
# [654]	validation-rmse:5.19846
# [655]	validation-rmse:5.19842
# [656]	validation-rmse:5.19835
# [657]	validation-rmse:5.19839
# [658]	validation-rmse:5.19850
# [659]	validation-rmse:5.19859
#   2%|▏         | 1/50 [00:15<12:32, 15.36s/trial, best loss: 5.198591467928773]
# /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [21:22:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:5.85340
# [1]	validation-rmse:5.45193
# [2]	validation-rmse:5.39195
# [3]	validation-rmse:5.38008
# [4]	validation-rmse:5.36756
# [5]	validation-rmse:5.36670
# [6]	validation-rmse:5.36663
# [7]	validation-rmse:5.35902
# [8]	validation-rmse:5.35670
# [9]	validation-rmse:5.35448
# [10]	validation-rmse:5.34931
# [11]	validation-rmse:5.34756
# [12]	validation-rmse:5.33260
# [13]	validation-rmse:5.33279
# [14]	validation-rmse:5.33391
# [15]	validation-rmse:5.33462
# [16]	validation-rmse:5.33538
# [17]	validation-rmse:5.33585
# [18]	validation-rmse:5.33268
# [19]	validation-rmse:5.33955
# [20]	validation-rmse:5.33851
# [21]	validation-rmse:5.34012
# [22]	validation-rmse:5.34038
# [23]	validation-rmse:5.34131
# [24]	validation-rmse:5.34219
# [25]	validation-rmse:5.34246
# [26]	validation-rmse:5.33966
# [27]	validation-rmse:5.34088
# [28]	validation-rmse:5.34320
# [29]	validation-rmse:5.34252
# [30]	validation-rmse:5.34448
# [31]	validation-rmse:5.34724
# [32]	validation-rmse:5.34952
# [33]	validation-rmse:5.34731
# [34]	validation-rmse:5.34801
# [35]	validation-rmse:5.34759
# [36]	validation-rmse:5.34736
# [37]	validation-rmse:5.34832
# [38]	validation-rmse:5.34796
# [39]	validation-rmse:5.34906
# [40]	validation-rmse:5.34532
# [41]	validation-rmse:5.34773
# [42]	validation-rmse:5.34814
# [43]	validation-rmse:5.34729
# [44]	validation-rmse:5.34917
# [45]	validation-rmse:5.34830
# [46]	validation-rmse:5.34871
# [47]	validation-rmse:5.35225
# [48]	validation-rmse:5.35264
# [49]	validation-rmse:5.35830
# [50]	validation-rmse:5.36026
# [51]	validation-rmse:5.36179
# [52]	validation-rmse:5.36327
# [53]	validation-rmse:5.36368
# [54]	validation-rmse:5.36507
# [55]	validation-rmse:5.36750
# [56]	validation-rmse:5.36815
# [57]	validation-rmse:5.36994
# [58]	validation-rmse:5.37055
# [59]	validation-rmse:5.37177
# [60]	validation-rmse:5.37387
# [61]	validation-rmse:5.37382
# [62]	validation-rmse:5.37584
#   4%|▍         | 2/50 [00:18<06:45,  8.44s/trial, best loss: 5.198591467928773]
# /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [21:22:33] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:6.14895
# [1]	validation-rmse:5.39926
# [2]	validation-rmse:5.24579
# [3]	validation-rmse:5.21091
# [4]	validation-rmse:5.19524
# [5]	validation-rmse:5.18790
# [6]	validation-rmse:5.18970
# [7]	validation-rmse:5.18547
# [8]	validation-rmse:5.18343
# [9]	validation-rmse:5.18053
# [10]	validation-rmse:5.17986
# [11]	validation-rmse:5.17886
# [12]	validation-rmse:5.17920
# [13]	validation-rmse:5.17801
# [14]	validation-rmse:5.17505
# [15]	validation-rmse:5.17551
# [16]	validation-rmse:5.17830
# [17]	validation-rmse:5.17917
# [18]	validation-rmse:5.18070
# [19]	validation-rmse:5.17468
# [20]	validation-rmse:5.17375
# [21]	validation-rmse:5.17277
# [22]	validation-rmse:5.17226
# [23]	validation-rmse:5.17043
# [24]	validation-rmse:5.17110
# [25]	validation-rmse:5.17310
# [26]	validation-rmse:5.17493
# [27]	validation-rmse:5.17508
# [28]	validation-rmse:5.17476
# [29]	validation-rmse:5.17479
# [30]	validation-rmse:5.17242
# [31]	validation-rmse:5.17334
# [32]	validation-rmse:5.17097
# [33]	validation-rmse:5.17054
# [34]	validation-rmse:5.16955
# [35]	validation-rmse:5.16917
# [36]	validation-rmse:5.16593
# [37]	validation-rmse:5.16510
# [38]	validation-rmse:5.16560
# [39]	validation-rmse:5.16482
# [40]	validation-rmse:5.16543
# [41]	validation-rmse:5.16524
# [42]	validation-rmse:5.16651
# [43]	validation-rmse:5.16739
# [44]	validation-rmse:5.16851
# [45]	validation-rmse:5.16806
# [46]	validation-rmse:5.16893
# [47]	validation-rmse:5.16899
# [48]	validation-rmse:5.17013
# [49]	validation-rmse:5.17224
# [50]	validation-rmse:5.17380
# [51]	validation-rmse:5.17450
# [52]	validation-rmse:5.17554
# [53]	validation-rmse:5.17544
# [54]	validation-rmse:5.17579
# [55]	validation-rmse:5.17657
# [56]	validation-rmse:5.17550
# [57]	validation-rmse:5.17602
# [58]	validation-rmse:5.17687
# [59]	validation-rmse:5.17709
# [60]	validation-rmse:5.17780
# [61]	validation-rmse:5.17920
# [62]	validation-rmse:5.17859
# [63]	validation-rmse:5.17991
# [64]	validation-rmse:5.17989
# [65]	validation-rmse:5.18146
# [66]	validation-rmse:5.18171
# [67]	validation-rmse:5.18212
# [68]	validation-rmse:5.18101
# ...
# [184]	validation-rmse:5.16252
# [185]	validation-rmse:5.16271
# [186]	validation-rmse:5.16227
# [187]	validation-rmse:5.16194
# [188]	validation-rmse:5.16129
# [189]	validation-rmse:5.16120
# [190]	validation-rmse:5.16125
# [191]	validation-rmse:5.16172
# [192]	validation-rmse:5.16144
# [193]	validation-rmse:5.16099
# [194]	validation-rmse:5.16119
# [195]	validation-rmse:5.16129
# [196]	validation-rmse:5.16152
# [197]	validation-rmse:5.16142
# [198]	validation-rmse:5.16177
# [199]	validation-rmse:5.16150
# [200]	validation-rmse:5.16156
# [201]	validation-rmse:5.15806
# [202]	validation-rmse:5.15639
# [203]	validation-rmse:5.15592
# [204]	validation-rmse:5.15531
# [205]	validation-rmse:5.15522
# [206]	validation-rmse:5.15520
# [207]	validation-rmse:5.15528
# [208]	validation-rmse:5.15628
# [209]	validation-rmse:5.15382
# [210]	validation-rmse:5.15263
# [211]	validation-rmse:5.15011
# [212]	validation-rmse:5.15003
# [213]	validation-rmse:5.15034
# [214]	validation-rmse:5.15018
# [215]	validation-rmse:5.15081
# [216]	validation-rmse:5.15044
# [217]	validation-rmse:5.15058
# [218]	validation-rmse:5.15066
# [219]	validation-rmse:5.15078
# [220]	validation-rmse:5.15121
# [221]	validation-rmse:5.14965
# [222]	validation-rmse:5.14979
# [223]	validation-rmse:5.14986
# [224]	validation-rmse:5.15031
# [225]	validation-rmse:5.15015
# [226]	validation-rmse:5.15047
# [227]	validation-rmse:5.15059
# [228]	validation-rmse:5.15059
# [229]	validation-rmse:5.15034
# [230]	validation-rmse:5.14996
# [231]	validation-rmse:5.15004
# [232]	validation-rmse:5.15001
# [233]	validation-rmse:5.14692
# [234]	validation-rmse:5.14672
# [235]	validation-rmse:5.14695
# [236]	validation-rmse:5.14700
# [237]	validation-rmse:5.14696
# [238]	validation-rmse:5.14697
# [239]	validation-rmse:5.14738
# [240]	validation-rmse:5.14647
# [241]	validation-rmse:5.14647
# [242]	validation-rmse:5.14661
# [243]	validation-rmse:5.14513
# [244]	validation-rmse:5.14509
# [245]	validation-rmse:5.14515
# [246]	validation-rmse:5.14590
# [247]	validation-rmse:5.14610
# [248]	validation-rmse:5.14568
# [249]	validation-rmse:5.14592
# [250]	validation-rmse:5.14599
# [251]	validation-rmse:5.14573
# [252]	validation-rmse:5.14555
# [253]	validation-rmse:5.14540
# [254]	validation-rmse:5.14547
# [255]	validation-rmse:5.14518
# [256]	validation-rmse:5.14512
# [257]	validation-rmse:5.14517
# [258]	validation-rmse:5.14473
# [259]	validation-rmse:5.14464
# [260]	validation-rmse:5.14466
# [261]	validation-rmse:5.14486
# [262]	validation-rmse:5.14486
# [263]	validation-rmse:5.14506
# [264]	validation-rmse:5.14475
# [265]	validation-rmse:5.14486
# [266]	validation-rmse:5.14488
# [267]	validation-rmse:5.14490
# [268]	validation-rmse:5.14480
# [269]	validation-rmse:5.14472
# [270]	validation-rmse:5.14475
# [271]	validation-rmse:5.14436
# [272]	validation-rmse:5.14423
# [273]	validation-rmse:5.14414
# [274]	validation-rmse:5.14418
# [275]	validation-rmse:5.14503
# [276]	validation-rmse:5.14366
# [277]	validation-rmse:5.14372
# [278]	validation-rmse:5.14367
# [279]	validation-rmse:5.14386
# [280]	validation-rmse:5.14413
# [281]	validation-rmse:5.14494
# [282]	validation-rmse:5.14472
# [283]	validation-rmse:5.14439
# [284]	validation-rmse:5.14499
# [285]	validation-rmse:5.14390
# [286]	validation-rmse:5.14415
# [287]	validation-rmse:5.14427
# [288]	validation-rmse:5.14424
# [289]	validation-rmse:5.14424
# [290]	validation-rmse:5.14452
# [291]	validation-rmse:5.14444
# [292]	validation-rmse:5.14437
# [293]	validation-rmse:5.14445
# [294]	validation-rmse:5.14490
# [295]	validation-rmse:5.14488
# [296]	validation-rmse:5.14454
# [297]	validation-rmse:5.14422
# [298]	validation-rmse:5.14450
# [299]	validation-rmse:5.14483
# [300]	validation-rmse:5.14448
# [301]	validation-rmse:5.14446
# [302]	validation-rmse:5.14434
# [303]	validation-rmse:5.14443
# [304]	validation-rmse:5.14436
# [305]	validation-rmse:5.14383
# [306]	validation-rmse:5.14379
# [307]	validation-rmse:5.14358
# [308]	validation-rmse:5.14298
# [309]	validation-rmse:5.14293
# [310]	validation-rmse:5.14312
# [311]	validation-rmse:5.14313
# [312]	validation-rmse:5.14312
# [313]	validation-rmse:5.14307
# [314]	validation-rmse:5.14074
# [315]	validation-rmse:5.14080
# [316]	validation-rmse:5.14016
# [317]	validation-rmse:5.14028
# [318]	validation-rmse:5.14070
# [319]	validation-rmse:5.14102
# [320]	validation-rmse:5.14187
# [321]	validation-rmse:5.14257
# [322]	validation-rmse:5.14270
# [323]	validation-rmse:5.14237
# [324]	validation-rmse:5.14169
# [325]	validation-rmse:5.14135
# [326]	validation-rmse:5.14138
# [327]	validation-rmse:5.13940
# [328]	validation-rmse:5.13946
# [329]	validation-rmse:5.13953
# [330]	validation-rmse:5.13939
# [331]	validation-rmse:5.13979
# [332]	validation-rmse:5.13992
# [333]	validation-rmse:5.13937
# [334]	validation-rmse:5.13942
# [335]	validation-rmse:5.13938
# [336]	validation-rmse:5.13940
# [337]	validation-rmse:5.13947
# [338]	validation-rmse:5.13961
# [339]	validation-rmse:5.13975
# [340]	validation-rmse:5.14029
# [341]	validation-rmse:5.14106
# [342]	validation-rmse:5.14125
# [343]	validation-rmse:5.14110
# [344]	validation-rmse:5.14099
# [345]	validation-rmse:5.14114
# [346]	validation-rmse:5.14056
# [347]	validation-rmse:5.14043
# [348]	validation-rmse:5.14043
# [349]	validation-rmse:5.14037
# [350]	validation-rmse:5.14085
# [351]	validation-rmse:5.14049
# [352]	validation-rmse:5.14116
# [353]	validation-rmse:5.14108
# [354]	validation-rmse:5.14101
# [355]	validation-rmse:5.14135
# [356]	validation-rmse:5.14161
# [357]	validation-rmse:5.14187
# [358]	validation-rmse:5.14216
# [359]	validation-rmse:5.14240
# [360]	validation-rmse:5.14287
# [361]	validation-rmse:5.14326
# [362]	validation-rmse:5.14351
# [363]	validation-rmse:5.14332
# [364]	validation-rmse:5.14378
# [365]	validation-rmse:5.14330
# [366]	validation-rmse:5.14352
# [367]	validation-rmse:5.14354
# [368]	validation-rmse:5.14356
# [369]	validation-rmse:5.14332
# [370]	validation-rmse:5.14334
# [371]	validation-rmse:5.14323
# [372]	validation-rmse:5.14274
# [373]	validation-rmse:5.14283
# [374]	validation-rmse:5.14315
# [375]	validation-rmse:5.14305
# [376]	validation-rmse:5.14286
# [377]	validation-rmse:5.14256
# [378]	validation-rmse:5.14271
# [379]	validation-rmse:5.14278
# [380]	validation-rmse:5.14254
# [381]	validation-rmse:5.14226
# [382]	validation-rmse:5.14214
# 100%|██████████| 50/50 [18:05<00:00, 21.71s/trial, best loss: 5.11472819026649]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run(nested=True):
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params= {
       "learning_rate":0.0923004677969142,
       "max_depth":43,
       "min_child_weight":3.158825903573778,
       "objective": "reg:linear",
       "reg_alpha": 0.020676403448522406,
       "reg_lambda": 0.2007432700080768,
       "seed": 42
    }

    # mlflow.xgboost.autolog()
    
    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred)**0.5
    mlflow.log_metric("rmse", rmse)


with open("models/preprocessor.b", "wb") as f_out:
    pickle.dump(dv, f_out)  # store the dv for future reuse
    
mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")



# mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [22:29:26] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.75190
# [1]	validation-rmse:8.25251
# [2]	validation-rmse:7.81542
# [3]	validation-rmse:7.43602
# [4]	validation-rmse:7.10675
# [5]	validation-rmse:6.82331
# [6]	validation-rmse:6.57866
# [7]	validation-rmse:6.37034
# [8]	validation-rmse:6.19239
# [9]	validation-rmse:6.04067
# [10]	validation-rmse:5.91083
# [11]	validation-rmse:5.80076
# [12]	validation-rmse:5.70727
# [13]	validation-rmse:5.62761
# [14]	validation-rmse:5.56129
# [15]	validation-rmse:5.50389
# [16]	validation-rmse:5.45596
# [17]	validation-rmse:5.41620
# [18]	validation-rmse:5.38238
# [19]	validation-rmse:5.35287
# [20]	validation-rmse:5.32736
# [21]	validation-rmse:5.30604
# [22]	validation-rmse:5.28679
# [23]	validation-rmse:5.27148
# [24]	validation-rmse:5.25761
# [25]	validation-rmse:5.24528
# [26]	validation-rmse:5.23584
# [27]	validation-rmse:5.22704
# [28]	validation-rmse:5.22049
# [29]	validation-rmse:5.21424
# [30]	validation-rmse:5.20864
# [31]	validation-rmse:5.20435
# [32]	validation-rmse:5.20088
# [33]	validation-rmse:5.19687
# [34]	validation-rmse:5.19378
# [35]	validation-rmse:5.19064
# [36]	validation-rmse:5.18787
# [37]	validation-rmse:5.18566
# [38]	validation-rmse:5.18369
# [39]	validation-rmse:5.18229
# [40]	validation-rmse:5.17992
# [41]	validation-rmse:5.17835
# [42]	validation-rmse:5.17678
# [43]	validation-rmse:5.17527
# [44]	validation-rmse:5.17366
# [45]	validation-rmse:5.17230
# [46]	validation-rmse:5.17106
# [47]	validation-rmse:5.16980
# [48]	validation-rmse:5.16883
# [49]	validation-rmse:5.16817
# [50]	validation-rmse:5.16788
# [51]	validation-rmse:5.16742
# [52]	validation-rmse:5.16716
# [53]	validation-rmse:5.16697
# [54]	validation-rmse:5.16639
# [55]	validation-rmse:5.16610
# [56]	validation-rmse:5.16527
# [57]	validation-rmse:5.16322
# [58]	validation-rmse:5.16238
# [59]	validation-rmse:5.16214
# [60]	validation-rmse:5.16167
# [61]	validation-rmse:5.16155
# [62]	validation-rmse:5.16099
# [63]	validation-rmse:5.16055
# [64]	validation-rmse:5.15984
# [65]	validation-rmse:5.15948
# [66]	validation-rmse:5.15908
# [67]	validation-rmse:5.15858
# [68]	validation-rmse:5.15830
# [69]	validation-rmse:5.15807
# [70]	validation-rmse:5.15784
# [71]	validation-rmse:5.15711
# [72]	validation-rmse:5.15628
# [73]	validation-rmse:5.15582
# [74]	validation-rmse:5.15565
# [75]	validation-rmse:5.15512
# [76]	validation-rmse:5.15462
# [77]	validation-rmse:5.15449
# [78]	validation-rmse:5.15430
# [79]	validation-rmse:5.15414
# [80]	validation-rmse:5.15379
# [81]	validation-rmse:5.15356
# [82]	validation-rmse:5.15249
# [83]	validation-rmse:5.15209
# [84]	validation-rmse:5.15146
# [85]	validation-rmse:5.15070
# [86]	validation-rmse:5.15039
# [87]	validation-rmse:5.15062
# [88]	validation-rmse:5.15019
# [89]	validation-rmse:5.15012
# [90]	validation-rmse:5.14997
# [91]	validation-rmse:5.14939
# [92]	validation-rmse:5.14892
# [93]	validation-rmse:5.14865
# [94]	validation-rmse:5.14862
# [95]	validation-rmse:5.14847
# [96]	validation-rmse:5.14832
# [97]	validation-rmse:5.14801
# [98]	validation-rmse:5.14763
# [99]	validation-rmse:5.14695
# [100]	validation-rmse:5.14692
# [101]	validation-rmse:5.14711
# [102]	validation-rmse:5.14678
# [103]	validation-rmse:5.14654
# [104]	validation-rmse:5.14627
# [105]	validation-rmse:5.14600
# [106]	validation-rmse:5.14608
# [107]	validation-rmse:5.14567
# [108]	validation-rmse:5.14550
# [109]	validation-rmse:5.14535
# [110]	validation-rmse:5.14523
# [111]	validation-rmse:5.14512
# [112]	validation-rmse:5.14491
# [113]	validation-rmse:5.14471
# [114]	validation-rmse:5.14446
# [115]	validation-rmse:5.14334
# [116]	validation-rmse:5.14312
# [117]	validation-rmse:5.14304
# [118]	validation-rmse:5.14287
# [119]	validation-rmse:5.14283
# [120]	validation-rmse:5.14302
# [121]	validation-rmse:5.14301
# [122]	validation-rmse:5.14276
# [123]	validation-rmse:5.14251
# [124]	validation-rmse:5.14231
# [125]	validation-rmse:5.14221
# [126]	validation-rmse:5.14208
# [127]	validation-rmse:5.14200
# [128]	validation-rmse:5.14180
# [129]	validation-rmse:5.14164
# [130]	validation-rmse:5.14124
# [131]	validation-rmse:5.14125
# [132]	validation-rmse:5.14052
# [133]	validation-rmse:5.14048
# [134]	validation-rmse:5.14026
# [135]	validation-rmse:5.14008
# [136]	validation-rmse:5.13958
# [137]	validation-rmse:5.13945
# [138]	validation-rmse:5.13896
# [139]	validation-rmse:5.13862
# [140]	validation-rmse:5.13873
# [141]	validation-rmse:5.13869
# [142]	validation-rmse:5.13898
# [143]	validation-rmse:5.13891
# [144]	validation-rmse:5.13878
# [145]	validation-rmse:5.13861
# [146]	validation-rmse:5.13861
# [147]	validation-rmse:5.13834
# [148]	validation-rmse:5.13828
# [149]	validation-rmse:5.13827
# [150]	validation-rmse:5.13815
# [151]	validation-rmse:5.13826
# [152]	validation-rmse:5.13811
# [153]	validation-rmse:5.13801
# [154]	validation-rmse:5.13786
# [155]	validation-rmse:5.13772
# [156]	validation-rmse:5.13748
# [157]	validation-rmse:5.13743
# [158]	validation-rmse:5.13676
# [159]	validation-rmse:5.13655
# [160]	validation-rmse:5.13620
# [161]	validation-rmse:5.13610
# [162]	validation-rmse:5.13560
# [163]	validation-rmse:5.13578
# [164]	validation-rmse:5.13563
# [165]	validation-rmse:5.13563
# [166]	validation-rmse:5.13548
# [167]	validation-rmse:5.13549
# [168]	validation-rmse:5.13535
# [169]	validation-rmse:5.13533
# [170]	validation-rmse:5.13532
# [171]	validation-rmse:5.13528
# [172]	validation-rmse:5.13519
# [173]	validation-rmse:5.13532
# [174]	validation-rmse:5.13504
# [175]	validation-rmse:5.13476
# [176]	validation-rmse:5.13483
# [177]	validation-rmse:5.13474
# [178]	validation-rmse:5.13476
# [179]	validation-rmse:5.13476
# [180]	validation-rmse:5.13462
# [181]	validation-rmse:5.13477
# [182]	validation-rmse:5.13473
# [183]	validation-rmse:5.13447
# [184]	validation-rmse:5.13451
# [185]	validation-rmse:5.13435
# [186]	validation-rmse:5.13425
# [187]	validation-rmse:5.13424
# [188]	validation-rmse:5.13404
# [189]	validation-rmse:5.13395
# [190]	validation-rmse:5.13380
# [191]	validation-rmse:5.13386
# [192]	validation-rmse:5.13372
# [193]	validation-rmse:5.13362
# [194]	validation-rmse:5.13375
# [195]	validation-rmse:5.13321
# [196]	validation-rmse:5.13297
# [197]	validation-rmse:5.13302
# [198]	validation-rmse:5.13295
# [199]	validation-rmse:5.13291
# [200]	validation-rmse:5.13285
# [201]	validation-rmse:5.13323
# [202]	validation-rmse:5.13307
# [203]	validation-rmse:5.13309
# [204]	validation-rmse:5.13305
# [205]	validation-rmse:5.13275
# [206]	validation-rmse:5.13172
# [207]	validation-rmse:5.13157
# [208]	validation-rmse:5.13160
# [209]	validation-rmse:5.13162
# [210]	validation-rmse:5.13156
# [211]	validation-rmse:5.13120
# [212]	validation-rmse:5.13105
# [213]	validation-rmse:5.13093
# [214]	validation-rmse:5.13080
# [215]	validation-rmse:5.13057
# [216]	validation-rmse:5.13072
# [217]	validation-rmse:5.13051
# [218]	validation-rmse:5.13056
# [219]	validation-rmse:5.13052
# [220]	validation-rmse:5.13047
# [221]	validation-rmse:5.13044
# [222]	validation-rmse:5.13017
# [223]	validation-rmse:5.13007
# [224]	validation-rmse:5.13005
# [225]	validation-rmse:5.12986
# [226]	validation-rmse:5.12980
# [227]	validation-rmse:5.12978
# [228]	validation-rmse:5.13015
# [229]	validation-rmse:5.13014
# [230]	validation-rmse:5.13018
# [231]	validation-rmse:5.13022
# [232]	validation-rmse:5.13019
# [233]	validation-rmse:5.13009
# [234]	validation-rmse:5.13009
# [235]	validation-rmse:5.13026
# [236]	validation-rmse:5.13025
# [237]	validation-rmse:5.13022
# [238]	validation-rmse:5.13021
# [239]	validation-rmse:5.13018
# [240]	validation-rmse:5.13023
# [241]	validation-rmse:5.12964
# [242]	validation-rmse:5.12959
# [243]	validation-rmse:5.12953
# [244]	validation-rmse:5.12930
# [245]	validation-rmse:5.12896
# [246]	validation-rmse:5.12893
# [247]	validation-rmse:5.12876
# [248]	validation-rmse:5.12884
# [249]	validation-rmse:5.12870
# [250]	validation-rmse:5.12854
# [251]	validation-rmse:5.12856
# [252]	validation-rmse:5.12840
# [253]	validation-rmse:5.12831
# [254]	validation-rmse:5.12805
# [255]	validation-rmse:5.12807
# [256]	validation-rmse:5.12806
# [257]	validation-rmse:5.12817
# [258]	validation-rmse:5.12798
# [259]	validation-rmse:5.12806
# [260]	validation-rmse:5.12790
# [261]	validation-rmse:5.12786
# [262]	validation-rmse:5.12807
# [263]	validation-rmse:5.12805
# [264]	validation-rmse:5.12810
# [265]	validation-rmse:5.12811
# [266]	validation-rmse:5.12806
# [267]	validation-rmse:5.12805
# [268]	validation-rmse:5.12805
# [269]	validation-rmse:5.12808
# [270]	validation-rmse:5.12802
# [271]	validation-rmse:5.12805
# [272]	validation-rmse:5.12803
# [273]	validation-rmse:5.12797
# [274]	validation-rmse:5.12810
# [275]	validation-rmse:5.12822
# [276]	validation-rmse:5.12818
# [277]	validation-rmse:5.12814
# [278]	validation-rmse:5.12813
# [279]	validation-rmse:5.12833
# [280]	validation-rmse:5.12822
# [281]	validation-rmse:5.12813
# [282]	validation-rmse:5.12766
# [283]	validation-rmse:5.12767
# [284]	validation-rmse:5.12753
# [285]	validation-rmse:5.12717
# [286]	validation-rmse:5.12724
# [287]	validation-rmse:5.12724
# [288]	validation-rmse:5.12729
# [289]	validation-rmse:5.12736
# [290]	validation-rmse:5.12714
# [291]	validation-rmse:5.12696
# [292]	validation-rmse:5.12700
# [293]	validation-rmse:5.12698
# [294]	validation-rmse:5.12680
# [295]	validation-rmse:5.12677
# [296]	validation-rmse:5.12675
# [297]	validation-rmse:5.12679
# [298]	validation-rmse:5.12674
# [299]	validation-rmse:5.12669
# [300]	validation-rmse:5.12662
# [301]	validation-rmse:5.12682
# [302]	validation-rmse:5.12697
# [303]	validation-rmse:5.12696
# [304]	validation-rmse:5.12702
# [305]	validation-rmse:5.12693
# [306]	validation-rmse:5.12697
# [307]	validation-rmse:5.12693
# [308]	validation-rmse:5.12710
# [309]	validation-rmse:5.12712
# [310]	validation-rmse:5.12706
# [311]	validation-rmse:5.12689
# [312]	validation-rmse:5.12702
# [313]	validation-rmse:5.12719
# [314]	validation-rmse:5.12715
# [315]	validation-rmse:5.12723
# [316]	validation-rmse:5.12727
# [317]	validation-rmse:5.12727
# [318]	validation-rmse:5.12708
# [319]	validation-rmse:5.12718
# [320]	validation-rmse:5.12723
# [321]	validation-rmse:5.12722
# [322]	validation-rmse:5.12721
# [323]	validation-rmse:5.12733
# [324]	validation-rmse:5.12717
# [325]	validation-rmse:5.12711
# [326]	validation-rmse:5.12703
# [327]	validation-rmse:5.12700
# [328]	validation-rmse:5.12704
# [329]	validation-rmse:5.12705
# [330]	validation-rmse:5.12691
# [331]	validation-rmse:5.12676
# [332]	validation-rmse:5.12673
# [333]	validation-rmse:5.12656
# [334]	validation-rmse:5.12626
# [335]	validation-rmse:5.12627
# [336]	validation-rmse:5.12627
# [337]	validation-rmse:5.12627
# [338]	validation-rmse:5.12628
# [339]	validation-rmse:5.12621
# [340]	validation-rmse:5.12627
# [341]	validation-rmse:5.12627
# [342]	validation-rmse:5.12631
# [343]	validation-rmse:5.12615
# [344]	validation-rmse:5.12617
# [345]	validation-rmse:5.12606
# [346]	validation-rmse:5.12572
# [347]	validation-rmse:5.12572
# [348]	validation-rmse:5.12574
# [349]	validation-rmse:5.12541
# [350]	validation-rmse:5.12518
# [351]	validation-rmse:5.12530
# [352]	validation-rmse:5.12507
# [353]	validation-rmse:5.12519
# [354]	validation-rmse:5.12527
# [355]	validation-rmse:5.12503
# [356]	validation-rmse:5.12545
# [357]	validation-rmse:5.12519
# [358]	validation-rmse:5.12525
# [359]	validation-rmse:5.12521
# [360]	validation-rmse:5.12545
# [361]	validation-rmse:5.12515
# [362]	validation-rmse:5.12534
# [363]	validation-rmse:5.12494
# [364]	validation-rmse:5.12488
# [365]	validation-rmse:5.12463
# [366]	validation-rmse:5.12466
# [367]	validation-rmse:5.12441
# [368]	validation-rmse:5.12427
# [369]	validation-rmse:5.12397
# [370]	validation-rmse:5.12412
# [371]	validation-rmse:5.12379
# [372]	validation-rmse:5.12376
# [373]	validation-rmse:5.12350
# [374]	validation-rmse:5.12368
# [375]	validation-rmse:5.12340
# [376]	validation-rmse:5.12338
# [377]	validation-rmse:5.12320
# [378]	validation-rmse:5.12340
# [379]	validation-rmse:5.12319
# [380]	validation-rmse:5.12294
# [381]	validation-rmse:5.12280
# [382]	validation-rmse:5.12289
# [383]	validation-rmse:5.12273
# [384]	validation-rmse:5.12257
# [385]	validation-rmse:5.12274
# [386]	validation-rmse:5.12249
# [387]	validation-rmse:5.12230
# [388]	validation-rmse:5.12251
# [389]	validation-rmse:5.12237
# [390]	validation-rmse:5.12201
# [391]	validation-rmse:5.12176
# [392]	validation-rmse:5.12162
# [393]	validation-rmse:5.12178
# [394]	validation-rmse:5.12164
# [395]	validation-rmse:5.12158
# [396]	validation-rmse:5.12141
# [397]	validation-rmse:5.12152
# [398]	validation-rmse:5.12152
# [399]	validation-rmse:5.12145
# [400]	validation-rmse:5.12150
# [401]	validation-rmse:5.12120
# [402]	validation-rmse:5.12134
# [403]	validation-rmse:5.12113
# [404]	validation-rmse:5.12131
# [405]	validation-rmse:5.12117
# [406]	validation-rmse:5.12129
# [407]	validation-rmse:5.12115
# [408]	validation-rmse:5.12122
# [409]	validation-rmse:5.12111
# [410]	validation-rmse:5.12119
# [411]	validation-rmse:5.12112
# [412]	validation-rmse:5.12098
# [413]	validation-rmse:5.12084
# [414]	validation-rmse:5.12086
# [415]	validation-rmse:5.12063
# [416]	validation-rmse:5.12083
# [417]	validation-rmse:5.12072
# [418]	validation-rmse:5.12079
# [419]	validation-rmse:5.12070
# [420]	validation-rmse:5.12056
# [421]	validation-rmse:5.12073
# [422]	validation-rmse:5.12060
# [423]	validation-rmse:5.12059
# [424]	validation-rmse:5.12063
# [425]	validation-rmse:5.12073
# [426]	validation-rmse:5.12054
# [427]	validation-rmse:5.12073
# [428]	validation-rmse:5.12049
# [429]	validation-rmse:5.12060
# [430]	validation-rmse:5.12058
# [431]	validation-rmse:5.12050
# [432]	validation-rmse:5.12033
# [433]	validation-rmse:5.12051
# [434]	validation-rmse:5.12035
# [435]	validation-rmse:5.12014
# [436]	validation-rmse:5.12018
# [437]	validation-rmse:5.12019
# [438]	validation-rmse:5.12031
# [439]	validation-rmse:5.12018
# [440]	validation-rmse:5.12013
# [441]	validation-rmse:5.12020
# [442]	validation-rmse:5.12010
# [443]	validation-rmse:5.12007
# [444]	validation-rmse:5.12003
# [445]	validation-rmse:5.12010
# [446]	validation-rmse:5.11995
# [447]	validation-rmse:5.11985
# [448]	validation-rmse:5.11997
# [449]	validation-rmse:5.11987
# [450]	validation-rmse:5.12002
# [451]	validation-rmse:5.12000
# [452]	validation-rmse:5.11994
# [453]	validation-rmse:5.11997
# [454]	validation-rmse:5.12003
# [455]	validation-rmse:5.12005
# [456]	validation-rmse:5.12006
# [457]	validation-rmse:5.11995
# [458]	validation-rmse:5.11970
# [459]	validation-rmse:5.11969
# [460]	validation-rmse:5.11969
# [461]	validation-rmse:5.11987
# [462]	validation-rmse:5.11971
# [463]	validation-rmse:5.11977
# [464]	validation-rmse:5.11974
# [465]	validation-rmse:5.11964
# [466]	validation-rmse:5.11964
# [467]	validation-rmse:5.11969
# [468]	validation-rmse:5.11961
# [469]	validation-rmse:5.11933
# [470]	validation-rmse:5.11945
# [471]	validation-rmse:5.11948
# [472]	validation-rmse:5.11942
# [473]	validation-rmse:5.11948
# [474]	validation-rmse:5.11946
# [475]	validation-rmse:5.11929
# [476]	validation-rmse:5.11929
# [477]	validation-rmse:5.11935
# [478]	validation-rmse:5.11941
# [479]	validation-rmse:5.11931
# [480]	validation-rmse:5.11923
# [481]	validation-rmse:5.11904
# [482]	validation-rmse:5.11901
# [483]	validation-rmse:5.11887
# [484]	validation-rmse:5.11891
# [485]	validation-rmse:5.11899
# [486]	validation-rmse:5.11891
# [487]	validation-rmse:5.11886
# [488]	validation-rmse:5.11894
# [489]	validation-rmse:5.11883
# [490]	validation-rmse:5.11887
# [491]	validation-rmse:5.11880
# [492]	validation-rmse:5.11886
# [493]	validation-rmse:5.11870
# [494]	validation-rmse:5.11863
# [495]	validation-rmse:5.11861
# [496]	validation-rmse:5.11859
# [497]	validation-rmse:5.11852
# [498]	validation-rmse:5.11848
# [499]	validation-rmse:5.11830
# [500]	validation-rmse:5.11825
# [501]	validation-rmse:5.11819
# [502]	validation-rmse:5.11819
# [503]	validation-rmse:5.11805
# [504]	validation-rmse:5.11783
# [505]	validation-rmse:5.11780
# [506]	validation-rmse:5.11761
# [507]	validation-rmse:5.11756
# [508]	validation-rmse:5.11728
# [509]	validation-rmse:5.11725
# [510]	validation-rmse:5.11732
# [511]	validation-rmse:5.11755
# [512]	validation-rmse:5.11765
# [513]	validation-rmse:5.11764
# [514]	validation-rmse:5.11777
# [515]	validation-rmse:5.11778
# [516]	validation-rmse:5.11763
# [517]	validation-rmse:5.11760
# [518]	validation-rmse:5.11748
# [519]	validation-rmse:5.11737
# [520]	validation-rmse:5.11737
# [521]	validation-rmse:5.11738
# [522]	validation-rmse:5.11719
# [523]	validation-rmse:5.11715
# [524]	validation-rmse:5.11704
# [525]	validation-rmse:5.11696
# [526]	validation-rmse:5.11686
# [527]	validation-rmse:5.11680
# [528]	validation-rmse:5.11680
# [529]	validation-rmse:5.11669
# [530]	validation-rmse:5.11646
# [531]	validation-rmse:5.11665
# [532]	validation-rmse:5.11661
# [533]	validation-rmse:5.11667
# [534]	validation-rmse:5.11658
# [535]	validation-rmse:5.11667
# [536]	validation-rmse:5.11653
# [537]	validation-rmse:5.11647
# [538]	validation-rmse:5.11626
# [539]	validation-rmse:5.11623
# [540]	validation-rmse:5.11604
# [541]	validation-rmse:5.11596
# [542]	validation-rmse:5.11604
# [543]	validation-rmse:5.11597
# [544]	validation-rmse:5.11580
# [545]	validation-rmse:5.11591
# [546]	validation-rmse:5.11582
# [547]	validation-rmse:5.11585
# [548]	validation-rmse:5.11560
# [549]	validation-rmse:5.11554
# [550]	validation-rmse:5.11558
# [551]	validation-rmse:5.11582
# [552]	validation-rmse:5.11570
# [553]	validation-rmse:5.11574
# [554]	validation-rmse:5.11591
# [555]	validation-rmse:5.11579
# [556]	validation-rmse:5.11578
# [557]	validation-rmse:5.11563
# [558]	validation-rmse:5.11564
# [559]	validation-rmse:5.11566
# [560]	validation-rmse:5.11570
# [561]	validation-rmse:5.11561
# [562]	validation-rmse:5.11578
# [563]	validation-rmse:5.11563
# [564]	validation-rmse:5.11562
# [565]	validation-rmse:5.11569
# [566]	validation-rmse:5.11568
# [567]	validation-rmse:5.11568
# [568]	validation-rmse:5.11573
# [569]	validation-rmse:5.11566
# [570]	validation-rmse:5.11563
# [571]	validation-rmse:5.11554
# [572]	validation-rmse:5.11547
# [573]	validation-rmse:5.11553
# [574]	validation-rmse:5.11549
# [575]	validation-rmse:5.11540
# [576]	validation-rmse:5.11543
# [577]	validation-rmse:5.11538
# [578]	validation-rmse:5.11527
# [579]	validation-rmse:5.11525
# [580]	validation-rmse:5.11524
# [581]	validation-rmse:5.11517
# [582]	validation-rmse:5.11509
# [583]	validation-rmse:5.11487
# [584]	validation-rmse:5.11492
# [585]	validation-rmse:5.11491
# [586]	validation-rmse:5.11497
# [587]	validation-rmse:5.11498
# [588]	validation-rmse:5.11492
# [589]	validation-rmse:5.11495
# [590]	validation-rmse:5.11485
# [591]	validation-rmse:5.11487
# [592]	validation-rmse:5.11507
# [593]	validation-rmse:5.11500
# [594]	validation-rmse:5.11504
# [595]	validation-rmse:5.11498
# [596]	validation-rmse:5.11493
# [597]	validation-rmse:5.11488
# [598]	validation-rmse:5.11486
# [599]	validation-rmse:5.11476
# [600]	validation-rmse:5.11474
# [601]	validation-rmse:5.11467
# [602]	validation-rmse:5.11468
# [603]	validation-rmse:5.11477
# [604]	validation-rmse:5.11461
# [605]	validation-rmse:5.11467
# [606]	validation-rmse:5.11466
# [607]	validation-rmse:5.11470
# [608]	validation-rmse:5.11474
# [609]	validation-rmse:5.11460
# [610]	validation-rmse:5.11464
# [611]	validation-rmse:5.11460
# [612]	validation-rmse:5.11458
# [613]	validation-rmse:5.11463
# [614]	validation-rmse:5.11442
# [615]	validation-rmse:5.11443
# [616]	validation-rmse:5.11449
# [617]	validation-rmse:5.11434
# [618]	validation-rmse:5.11420
# [619]	validation-rmse:5.11428
# [620]	validation-rmse:5.11425
# [621]	validation-rmse:5.11425
# [622]	validation-rmse:5.11441
# [623]	validation-rmse:5.11437
# [624]	validation-rmse:5.11421
# [625]	validation-rmse:5.11438
# [626]	validation-rmse:5.11435
# [627]	validation-rmse:5.11439
# [628]	validation-rmse:5.11440
# [629]	validation-rmse:5.11422
# [630]	validation-rmse:5.11432
# [631]	validation-rmse:5.11439
# [632]	validation-rmse:5.11436
# [633]	validation-rmse:5.11437
# [634]	validation-rmse:5.11432
# [635]	validation-rmse:5.11443
# [636]	validation-rmse:5.11439
# [637]	validation-rmse:5.11439
# [638]	validation-rmse:5.11427
# [639]	validation-rmse:5.11412
# [640]	validation-rmse:5.11414
# [641]	validation-rmse:5.11402
# [642]	validation-rmse:5.11395
# [643]	validation-rmse:5.11375
# [644]	validation-rmse:5.11379
# [645]	validation-rmse:5.11377
# [646]	validation-rmse:5.11369
# [647]	validation-rmse:5.11372
# [648]	validation-rmse:5.11367
# [649]	validation-rmse:5.11368
# [650]	validation-rmse:5.11374
# [651]	validation-rmse:5.11378
# [652]	validation-rmse:5.11384
# [653]	validation-rmse:5.11388
# [654]	validation-rmse:5.11390
# [655]	validation-rmse:5.11386
# [656]	validation-rmse:5.11390
# [657]	validation-rmse:5.11377
# [658]	validation-rmse:5.11383
# [659]	validation-rmse:5.11374
# [660]	validation-rmse:5.11371
# [661]	validation-rmse:5.11368
# [662]	validation-rmse:5.11375
# [663]	validation-rmse:5.11382
# [664]	validation-rmse:5.11387
# [665]	validation-rmse:5.11372
# [666]	validation-rmse:5.11379
# [667]	validation-rmse:5.11391
# [668]	validation-rmse:5.11395
# [669]	validation-rmse:5.11391
# [670]	validation-rmse:5.11396
# [671]	validation-rmse:5.11398
# [672]	validation-rmse:5.11408
# [673]	validation-rmse:5.11407
# [674]	validation-rmse:5.11406
# [675]	validation-rmse:5.11421
# [676]	validation-rmse:5.11416
# [677]	validation-rmse:5.11418
# [678]	validation-rmse:5.11416
# [679]	validation-rmse:5.11415
# [680]	validation-rmse:5.11410
# [681]	validation-rmse:5.11417
# [682]	validation-rmse:5.11413
# [683]	validation-rmse:5.11408
# [684]	validation-rmse:5.11407
# [685]	validation-rmse:5.11415
# [686]	validation-rmse:5.11417
# [687]	validation-rmse:5.11451
# [688]	validation-rmse:5.11446
# [689]	validation-rmse:5.11447
# [690]	validation-rmse:5.11450
# [691]	validation-rmse:5.11453
# [692]	validation-rmse:5.11450
# [693]	validation-rmse:5.11449
# [694]	validation-rmse:5.11451
# [695]	validation-rmse:5.11453
# [696]	validation-rmse:5.11457
# [697]	validation-rmse:5.11463
# [698]	validation-rmse:5.11473
# 2025/04/01 22:29:54 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [22:29:54] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 31
#      28     mlflow.log_metric("rmse", rmse)
#      30 with open("models/xgb.bin", "wb") as f_out:
# ---> 31     pickle.dump((dv,xgb), f_out)  # store the dv for future reuse
#      33 mlflow.log_artifact("models/xgb.bin", artifact_path="models_pickle")
#      35 # mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
#
# TypeError: cannot pickle 'module' object

# %%
with mlflow.start_run():
    

   best_params= {"objective": 'reg:squarederror',
                 "n_estimators" :100,
                 "learning_rate":0.0923004677969142,
                 "max_depth":40,
                 "min_child_weight":3.158825903573778,
                 "objective": "reg:linear",
                 "reg_alpha": 0.020676403448522406,
                 "reg_lambda": 0.2007432700080768,
                 "seed": 42
                 }


   xgb_regressor = xgb.XGBRegressor(**best_params)

   # mlflow.xgboost.autolog()
   
   xgb_regressor.fit(X_train, y_train)
   y_pred = xgb_regressor.predict(X_val)

   # Evaluate the model

   rmse = mean_squared_error(y_val, y_pred)**0.5
   mlflow.log_metric("rmse", rmse)
   with open("models/xgb.bin", "wb") as f_out:
      pickle.dump((dv,xgb_regressor), f_out)  

mlflow.log_artifact("models/xgb.bin", artifact_path="models_pickle")
# Out:
# /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [23:45:56] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# 2025/04/01 23:46:03 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [23:46:03] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."

# %%
#load model from saved artifact 
logged_model ='runs:/c5fd346b28394d5faf39d881a163b7b4/models_mlflow'
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: c5fd346b28394d5faf39d881a163b7b4

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
xgboost_model

# %%
y_pred= xgboost_model.predict(valid)

# %%
y_pred[:3]
# Out:
# array([22.335491, 20.831606, 24.71197 ], dtype=float32)

# %% [markdown]
# ## Options 2

# %%
#if we use artifact instead
artifact_path = "models_pickle/xgb.bin"
run_id = "50215fbe793a49f7bc383d7c5a347586"
local_path = mlflow.artifacts.download_artifacts(
    run_id=run_id,
    artifact_path=artifact_path
    )

# %%
# Load with XGBoost
with open(local_path, "rb") as f:
    model = pickle.load(f)

# %%
dv, xgb_model = model

# %%
y_pred_bin= xgb_model.predict(X_val)

# %%
y_pred_bin[:3]
# Out:
# array([21.646782, 21.360643, 24.527328], dtype=float32)

# %%
import os
print("File path:", local_path)
print("File size:", os.path.getsize(local_path), "bytes")
# Out:
# File path: /Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1/50215fbe793a49f7bc383d7c5a347586/artifacts/models_pickle/xgb.bin
# File size: 4387188 bytes

# %% [markdown]
# ##  Log serveral models  for  prepairation of model registry

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()
dv = DictVectorizer()
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "data/green_tripdata_2023-01.parquet")
        mlflow.log_param("valid-data-path", "data/green_tripdata_2023-02.parquet")
    

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred)**0.5
        mlflow.log_metric("rmse", rmse)
        with open("models/preprocessor.b", "wb") as f_out:
            pickle.dump((dv,mlmodel), f_out)  

        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
# Out:
# 2025/04/03 20:07:21 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.21.3, required: mlflow==2.21.2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# 2025/04/03 20:07:33 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.21.3, required: mlflow==2.21.2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# 2025/04/03 20:13:59 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.21.3, required: mlflow==2.21.2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# /Users/zihaozhou/.conda/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 2025/04/03 20:14:18 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.21.3, required: mlflow==2.21.2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.

# %%
from mlflow.tracking import MlflowClient
mlflow_tracking_uri = "sqlite:///mlflow.db"
client = MlflowClient(tracking_uri=mlflow_tracking_uri)

# %%
experiments = client.search_experiments()
for exp in experiments:
    print (f'Nane: {exp.name} , ID:{exp.experiment_id}, artifact location :{exp.artifact_location}')
# Out:
# Nane: nyc-taxi-experiment , ID:1, artifact location :/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1
# Nane: Default , ID:0, artifact location :mlflow-artifacts:/0

# %%
from mlflow.entities import ViewType
runs = client.search_runs(experiment_ids='1',
                          filter_string='',
                          run_view_type= ViewType.ACTIVE_ONLY,
                          max_results=5,
                          order_by=['metrics.rmse ASC']
                          )
for run in runs:
    print(f"run id: {run.info.run_id}, rmse : {run.data.metrics['rmse']:.4f}")
# Out:
# run id: 23b3fda0ae8a483c9cd0f59389d7a4e4, rmse : 5.1147
# run id: f10256a9713c443e977523ac4a695a1d, rmse : 5.1147
# run id: 1cbcfc48cbd24c7ab4afab6656c2c242, rmse : 5.1147
# run id: f9610d3a40c64bdfadaab62e54ba8eb0, rmse : 5.1147
# run id: 9388a15b64f443c695cd88f8fb136afa, rmse : 5.1147

# %%
from mlflow.entities import ViewType
runs = client.search_runs(experiment_ids='1',
                          filter_string='metric.rmse < 5.12',
                          run_view_type= ViewType.ACTIVE_ONLY,
                          max_results=10,
                          order_by=['metrics.rmse ASC']
                          )
for run in runs:
    print(f"run id: {run.info.run_id}, rmse : {run.data.metrics['rmse']:.4f}")
# Out:
# run id: 23b3fda0ae8a483c9cd0f59389d7a4e4, rmse : 5.1147
# run id: f10256a9713c443e977523ac4a695a1d, rmse : 5.1147
# run id: 1cbcfc48cbd24c7ab4afab6656c2c242, rmse : 5.1147
# run id: f9610d3a40c64bdfadaab62e54ba8eb0, rmse : 5.1147
# run id: 9388a15b64f443c695cd88f8fb136afa, rmse : 5.1147
# run id: 97fbf6c3cba14d4e9a64df93b2c47593, rmse : 5.1157

# %%
# next to find models hving lowest rmse and duration 
run_infos = []
runs = client.search_runs(experiment_ids='1',
                          filter_string='',
                          run_view_type= ViewType.ACTIVE_ONLY,
                          max_results=10,
                          order_by=['metrics.rmse ASC']
                          )
for run in runs:
    rmse = run.data.metrics.get("rmse")
    start = run.info.start_time
    end = run.info.end_time
    if rmse is not None and start is not None and end is not None:
        duration = (end - start) / 1000  # Convert ms to seconds
        run_infos.append({
            "run_id": run.info.run_id,
            "rmse": rmse,
            "duration_sec": duration
        })

run_infos
# Out:
# [{'run_id': '23b3fda0ae8a483c9cd0f59389d7a4e4',
#   'rmse': 5.11472819026649,
#   'duration_sec': 33.625},
#  {'run_id': 'f10256a9713c443e977523ac4a695a1d',
#   'rmse': 5.11472819026649,
#   'duration_sec': 33.245},
#  {'run_id': '1cbcfc48cbd24c7ab4afab6656c2c242',
#   'rmse': 5.11472819026649,
#   'duration_sec': 43.873},
#  {'run_id': 'f9610d3a40c64bdfadaab62e54ba8eb0',
#   'rmse': 5.11472819026649,
#   'duration_sec': 36.964},
#  {'run_id': '9388a15b64f443c695cd88f8fb136afa',
#   'rmse': 5.11472819026649,
#   'duration_sec': 262.577},
#  {'run_id': '97fbf6c3cba14d4e9a64df93b2c47593',
#   'rmse': 5.115681014129676,
#   'duration_sec': 18.229},
#  {'run_id': '4b784513b8e746489ae29d9e632dd551',
#   'rmse': 5.12187644499111,
#   'duration_sec': 13.135},
#  {'run_id': 'd0a87225223f4dc88837b3c9e74289b7',
#   'rmse': 5.126511500125477,
#   'duration_sec': 26.849},
#  {'run_id': 'f39a48180fa74a54a0652fe896686c32',
#   'rmse': 5.128890829962695,
#   'duration_sec': 25.31},
#  {'run_id': 'b9c4d8c6330a4f7aa10338363e9fd7de',
#   'rmse': 5.1293643771073025,
#   'duration_sec': 29.405}]

# %%
#sort 
sorted_runs = sorted(
    run_infos,
    key=lambda x: (x["rmse"], x["duration_sec"]))[:3]  # First by rmse, then duration

# %%
sorted_runs
# Out:
# [{'run_id': 'f10256a9713c443e977523ac4a695a1d',
#   'rmse': 5.11472819026649,
#   'duration_sec': 33.245},
#  {'run_id': '23b3fda0ae8a483c9cd0f59389d7a4e4',
#   'rmse': 5.11472819026649,
#   'duration_sec': 33.625},
#  {'run_id': 'f9610d3a40c64bdfadaab62e54ba8eb0',
#   'rmse': 5.11472819026649,
#   'duration_sec': 36.964}]

# %%
# I would register the 3 models with least rsme and duration 
for i in sorted_runs:
    model_uri = f"runs:/{i.get('run_id')}/model"
    mlflow.register_model(model_uri=model_uri,)name='nyc-taxi-regiessor'
# Out:
# Registered model 'nyc-taxi-regiessor' already exists. Creating a new version of this model...
# Created version '3' of model 'nyc-taxi-regiessor'.
# Registered model 'nyc-taxi-regiessor' already exists. Creating a new version of this model...
# Created version '4' of model 'nyc-taxi-regiessor'.
# Registered model 'nyc-taxi-regiessor' already exists. Creating a new version of this model...
# Created version '5' of model 'nyc-taxi-regiessor'.

# %%
# let check what models we have under registry
all_versions = client.search_model_versions(filter_string= "name='nyc-taxi-regiessor'")

for v in all_versions:
    print(f"Version: {v.version}, Stage: {v.current_stage}, Status: {v.status}, Aliases: {v.aliases}")
# Out:
# Version: 5, Stage: None, Status: READY, Aliases: []
# Version: 4, Stage: None, Status: READY, Aliases: []
# Version: 3, Stage: None, Status: READY, Aliases: []
# Version: 2, Stage: None, Status: READY, Aliases: []
# Version: 1, Stage: None, Status: READY, Aliases: []

# %%
client.transition_model_version_stage(name= 'nyc-taxi-regiessor',
                                      version=3,
                                      stage='production',
                                      archive_existing_versions=False)
# Out:
# /var/folders/xv/p1z69rt949l1ttxwv1f6vr340000gn/T/ipykernel_39856/1600414815.py:1: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(name= 'nyc-taxi-regiessor',
# <ModelVersion: aliases=[], creation_timestamp=1743718988470, current_stage='Production', description=None, last_updated_timestamp=1743721981238, name='nyc-taxi-regiessor', run_id='f10256a9713c443e977523ac4a695a1d', run_link=None, source='/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1/f10256a9713c443e977523ac4a695a1d/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %%
client.transition_model_version_stage(name= 'nyc-taxi-regiessor',
                                      version=4,
                                      stage='staging',
                                      archive_existing_versions=False)
# Out:
# /var/folders/xv/p1z69rt949l1ttxwv1f6vr340000gn/T/ipykernel_39856/2275782555.py:1: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(name= 'nyc-taxi-regiessor',
# <ModelVersion: aliases=[], creation_timestamp=1743718988487, current_stage='Staging', description=None, last_updated_timestamp=1743722134451, name='nyc-taxi-regiessor', run_id='23b3fda0ae8a483c9cd0f59389d7a4e4', run_link=None, source='/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1/23b3fda0ae8a483c9cd0f59389d7a4e4/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=4>

# %%
# we can also update the description 
client.update_registered_model(name='nyc-taxi-regiessor',
                               description='This is the registry for ny taxi fare project'
                               )
# Out:
# <RegisteredModel: aliases={'challenger': 1, 'champion': 2}, creation_timestamp=1743650476176, description='This is the registry for ny taxi fare project', last_updated_timestamp=1743722673960, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1743718988498, current_stage='None', description=None, last_updated_timestamp=1743718988498, name='nyc-taxi-regiessor', run_id='f9610d3a40c64bdfadaab62e54ba8eb0', run_link=None, source='/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1/f9610d3a40c64bdfadaab62e54ba8eb0/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=5>,
#  <ModelVersion: aliases=[], creation_timestamp=1743718988470, current_stage='Production', description=None, last_updated_timestamp=1743721981238, name='nyc-taxi-regiessor', run_id='f10256a9713c443e977523ac4a695a1d', run_link=None, source='/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1/f10256a9713c443e977523ac4a695a1d/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>,
#  <ModelVersion: aliases=[], creation_timestamp=1743718988487, current_stage='Staging', description=None, last_updated_timestamp=1743722134451, name='nyc-taxi-regiessor', run_id='23b3fda0ae8a483c9cd0f59389d7a4e4', run_link=None, source='/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1/23b3fda0ae8a483c9cd0f59389d7a4e4/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=4>], name='nyc-taxi-regiessor', tags={}>

# %%
#we can also update the description for each version of model 
client.update_model_version(name='nyc-taxi-regiessor',
                            version= 3,
                            description='The model is transit to production'
                            )
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1743718988470, current_stage='Production', description='The model is transit to production', last_updated_timestamp=1743722789499, name='nyc-taxi-regiessor', run_id='f10256a9713c443e977523ac4a695a1d', run_link=None, source='/Users/zihaozhou/VS_code/mlops-zoomcamp/02-experiment-tracking/mlruns/1/f10256a9713c443e977523ac4a695a1d/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %% [markdown]
# ### Comparing versions and selecting the new "Production" model
#
# In the last section, we will retrieve models registered in the model registry and compare their performance on an unseen test set. The idea is to simulate the scenario in which a deployment engineer has to interact with the model registry to decide whether to update the model version that is in production or not.
#
# These are the steps:
#
# 1. Load the test dataset, which corresponds to the NYC Green Taxi data from the month of March 2021.
# 2. Download the `DictVectorizer` that was fitted using the training data and saved to MLflow as an artifact, and load it with pickle.
# 3. Preprocess the test set using the `DictVectorizer` so we can properly feed the regressors.
# 4. Make predictions on the test set using the model versions that are currently in the "Staging" and "Production" stages, and compare their performance.
# 5. Based on the results, update the "Production" model version accordingly.
#
#
# **Note: the model registry doesn't actually deploy the model to production when you transition a model to the "Production" stage, it just assign a label to that model version. You should complement the registry with some CI/CD code that does the actual deployment.**

# %%
from sklearn.metrics import root_mean_squared_error
import pandas as pd


def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df


def preprocess(df, dv):
    df['PU_DO'] = df['PULocationID'] + '_' + df['DOLocationID']
    categorical = ['PU_DO']
    numerical = ['trip_distance']
    train_dicts = df[categorical + numerical].to_dict(orient='records')
    return dv.transform(train_dicts)


def test_model(name, stage, X_test, y_test):
    model = mlflow.pyfunc.load_model(f"models:/{name}/{stage}")
    y_pred = model.predict(X_test)
    return {"rmse": root_mean_squared_error(y_test, y_pred)}

# %%
df = read_dataframe('data/green_tripdata_2023-03.parquet')

# %%
with open('models/preprocessor.b','rb') as f:
    dv,model = pickle.load(f)

# %%
X_test = preprocess(df,dv)

# %%
target = "duration"
y_test = df[target].values

# %%
# %time test_model(name='nyc-taxi-regiessor', stage="Production", X_test=X_test, y_test=y_test)
# Out:
# 2025/04/03 20:19:00 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.21.3, required: mlflow==2.21.2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# CPU times: user 16.5 s, sys: 391 ms, total: 16.9 s
# Wall time: 1.89 s
# {'rmse': 5.344813683865913}

# %%
# %time test_model(name='nyc-taxi-regiessor', stage="Staging", X_test=X_test, y_test=y_test)
# Out:
# 2025/04/03 20:19:17 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 2.21.3, required: mlflow==2.21.2)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# CPU times: user 15.8 s, sys: 292 ms, total: 16.1 s
# Wall time: 1.78 s
# {'rmse': 5.344813683865913}
